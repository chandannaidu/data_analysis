# %%
import pandas as pd
import numpy as np

# %%
nba=pd.read_csv("nba.csv")
nba.head(10)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 8   Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9   Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# ...

# %%
nba.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
nba.index
# Out:
# RangeIndex(start=0, stop=458, step=1)

# %%
nba.values
# Out:
# array([['Avery Bradley', 'Boston Celtics', 0.0, ..., 180.0, 'Texas',
#         7730337.0],
#        ['Jae Crowder', 'Boston Celtics', 99.0, ..., 235.0, 'Marquette',
#         6796117.0],
#        ['John Holland', 'Boston Celtics', 30.0, ..., 205.0,
#         'Boston University', nan],
#        ...,
#        ['Tibor Pleiss', 'Utah Jazz', 21.0, ..., 256.0, nan, 2900000.0],
#        ['Jeff Withey', 'Utah Jazz', 24.0, ..., 231.0, 'Kansas', 947276.0],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=object)

# %%
#series
a=pd.Series(np.random.randint(10,30,40))
a.values
# Out:
# array([21, 16, 26, 26, 24, 28, 22, 25, 20, 15, 26, 14, 24, 19, 20, 13, 12,
#        20, 15, 22, 10, 15, 29, 25, 15, 13, 21, 22, 27, 10, 12, 15, 24, 18,
#        23, 19, 21, 13, 28, 24])

# %%
nba.shape
# Out:
# (458, 9)

# %%
nba.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
nba.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
nba.axes
# Out:
# [RangeIndex(start=0, stop=458, step=1),
#  Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#         'College', 'Salary'],
#        dtype='object')]

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null object
# Number      457 non-null float64
# Position    457 non-null object
# Age         457 non-null float64
# Height      457 non-null object
# Weight      457 non-null float64
# College     373 non-null object
# Salary      446 non-null float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
nba.get_dtype_counts()
# Out:
# float64    4
# object     5
# dtype: int64

# %% [markdown]
# # difference btw shared method

# %%
rev=pd.read_csv("revenue.csv",index_col = "Date")
rev.head(3)
# Out:
#         New York  Los Angeles  Miami
# Date
# 1/1/16       985          122    499
# 1/2/16       738          788    534
# 1/3/16        14           20    933

# %%
S = pd.Series([1,2,3])
S
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
rev.sum()
# Out:
# New York       5475
# Los Angeles    5134
# Miami          5641
# dtype: int64

# %%
rev.sum(axis = 0) #column wise
# Out:
# New York       5475
# Los Angeles    5134
# Miami          5641
# dtype: int64

# %%
rev.sum(axis = "index")  #column wise
# Out:
# New York       5475
# Los Angeles    5134
# Miami          5641
# dtype: int64

# %%
rev.sum(axis = 1)  #row wise (axis = 'columns') works
# Out:
# Date
# 1/1/16     1606
# 1/2/16     2060
# 1/3/16      967
# 1/4/16     2519
# 1/5/16      438
# 1/6/16     1935
# 1/7/16     1234
# 1/8/16     2313
# 1/9/16     2623
# 1/10/16     555
# dtype: int64

# %% [markdown]
# # selecting one column from dataframe

# %%
nba = pd.read_csv("nba.csv")
nba.head(6)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# 4                NaN   5000000.0
# 5                NaN  12000000.0

# %%
nba.Name.head(6)
# Out:
# 0    Avery Bradley
# 1      Jae Crowder
# 2     John Holland
# 3      R.J. Hunter
# 4    Jonas Jerebko
# 5     Amir Johnson
# Name: Name, dtype: object

# %%
nba.Name
nba.Salary

Output = None

# %%
nba['Name']
nba['Salary']
# Out:
# 0       7730337.0
# 1       6796117.0
# 2             NaN
# 3       1148640.0
# 4       5000000.0
# 5      12000000.0
# 6       1170960.0
# 7       2165160.0
# 8       1824360.0
# 9       3431040.0
# 10      2569260.0
# 11      6912869.0
# 12      3425510.0
# 13      1749840.0
# 14      2616975.0
# 15      3425510.0
# 16       845059.0
# 17      1500000.0
# 18      1335480.0
# 19      6300000.0
# 20      1599840.0
# 21       134215.0
# 22      1500000.0
# 23     19689000.0
# 24      1140240.0
# 25       947276.0
# 26       981348.0
# 27       947276.0
# 28       947276.0
# 29     11235955.0
#           ...
# 428     8042895.0
# 429      625093.0
# 430      947276.0
# 431     6980802.0
# 432     2894059.0
# 433     6000000.0
# 434     5016000.0
# 435     3075880.0
# 436     4236287.0
# 437     2525160.0
# 438      525093.0
# 439     1415520.0
# 440     2854940.0
# 441     2637720.0
# 442     4775000.0
# 443     2658240.0
# 444     9463484.0
# 445     3777720.0
# 446    12000000.0
# ...

# %%
type(nba['Name'])
# Out:
# pandas.core.series.Series

# %%
nba['Name'].head()
# Out:
# 0    Avery Bradley
# 1      Jae Crowder
# 2     John Holland
# 3      R.J. Hunter
# 4    Jonas Jerebko
# Name: Name, dtype: object

# %% [markdown]
# # select two or more columns from the dataframe

# %%
nba = pd.read_csv('nba.csv')
nba.head(7)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# 4                NaN   5000000.0
# 5                NaN  12000000.0
# 6                LSU   1170960.0

# %%
nba[['Name','Age']].head(4)
# Out:
#             Name   Age
# 0  Avery Bradley  25.0
# 1    Jae Crowder  25.0
# 2   John Holland  27.0
# 3    R.J. Hunter  22.0

# %%
type(nba[['Name','Age']].head(4))
# Out:
# pandas.core.frame.DataFrame

# %%
select = ['Name','Age','Salary']
nba[select].head(6)
# Out:
#             Name   Age      Salary
# 0  Avery Bradley  25.0   7730337.0
# 1    Jae Crowder  25.0   6796117.0
# 2   John Holland  27.0         NaN
# 3    R.J. Hunter  22.0   1148640.0
# 4  Jonas Jerebko  29.0   5000000.0
# 5   Amir Johnson  29.0  12000000.0

# %%
select = ['Name','Age','Salary']
for i in select:
    print(nba[i])
# Out:
# 0                Avery Bradley
# 1                  Jae Crowder
# 2                 John Holland
# 3                  R.J. Hunter
# 4                Jonas Jerebko
# 5                 Amir Johnson
# 6                Jordan Mickey
# 7                 Kelly Olynyk
# 8                 Terry Rozier
# 9                 Marcus Smart
# 10             Jared Sullinger
# 11               Isaiah Thomas
# 12                 Evan Turner
# 13                 James Young
# 14                Tyler Zeller
# 15            Bojan Bogdanovic
# 16                Markel Brown
# 17             Wayne Ellington
# 18     Rondae Hollis-Jefferson
# 19                Jarrett Jack
# 20              Sergey Karasev
# 21             Sean Kilpatrick
# 22                Shane Larkin
# 23                 Brook Lopez
# 24            Chris McCullough
# 25                 Willie Reed
# 26             Thomas Robinson
# 27                  Henry Sims
# 28                Donald Sloan
# 29              Thaddeus Young
# ...

# %%
nba['sports'] = 'chandan'

# %%
nba.head(7)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
#
#              College      Salary   sports
# 0              Texas   7730337.0  chandan
# 1          Marquette   6796117.0  chandan
# 2  Boston University         NaN  chandan
# 3      Georgia State   1148640.0  chandan
# 4                NaN   5000000.0  chandan
# 5                NaN  12000000.0  chandan
# 6                LSU   1170960.0  chandan

# %%
nba.insert(4,column='some_numberr',value=np.random.randn(458))
nba
# Out:
#                         Name                    Team  Number Position  \
# 0              Avery Bradley          Boston Celtics     0.0       PG
# 1                Jae Crowder          Boston Celtics    99.0       SF
# 2               John Holland          Boston Celtics    30.0       SG
# 3                R.J. Hunter          Boston Celtics    28.0       SG
# 4              Jonas Jerebko          Boston Celtics     8.0       PF
# 5               Amir Johnson          Boston Celtics    90.0       PF
# 6              Jordan Mickey          Boston Celtics    55.0       PF
# 7               Kelly Olynyk          Boston Celtics    41.0        C
# 8               Terry Rozier          Boston Celtics    12.0       PG
# 9               Marcus Smart          Boston Celtics    36.0       PG
# 10           Jared Sullinger          Boston Celtics     7.0        C
# 11             Isaiah Thomas          Boston Celtics     4.0       PG
# ...

# %% [markdown]
# # Broadcasting operation

# %%
nba = pd.read_csv('nba.csv')
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba['Age'].add(5)
nba['Age'] + 5
# Out:
# 0      30.0
# 1      30.0
# 2      32.0
# 3      27.0
# 4      34.0
# 5      34.0
# 6      26.0
# 7      30.0
# 8      27.0
# 9      27.0
# 10     29.0
# 11     32.0
# 12     32.0
# 13     25.0
# 14     31.0
# 15     32.0
# 16     29.0
# 17     33.0
# 18     26.0
# 19     37.0
# 20     27.0
# 21     31.0
# 22     28.0
# 23     33.0
# 24     26.0
# 25     31.0
# 26     30.0
# 27     31.0
# 28     33.0
# 29     32.0
#        ...
# 428    30.0
# 429    28.0
# 430    29.0
# 431    32.0
# 432    28.0
# 433    33.0
# 434    39.0
# 435    29.0
# 436    30.0
# 437    29.0
# 438    28.0
# 439    31.0
# 440    35.0
# 441    25.0
# 442    33.0
# 443    28.0
# 444    29.0
# 445    25.0
# 446    29.0
# 447    28.0
# 448    31.0
# 449    28.0
# 450    33.0
# 451    31.0
# 452    25.0
# 453    31.0
# 454    29.0
# 455    31.0
# 456    31.0
# 457     NaN
# Name: Age, Length: 458, dtype: float64

# %%
nba["Salary"].sub(100000)
nba['Salary'] - 100000
# Out:
# 0       7630337.0
# 1       6696117.0
# 2             NaN
# 3       1048640.0
# 4       4900000.0
# 5      11900000.0
# 6       1070960.0
# 7       2065160.0
# 8       1724360.0
# 9       3331040.0
# 10      2469260.0
# 11      6812869.0
# 12      3325510.0
# 13      1649840.0
# 14      2516975.0
# 15      3325510.0
# 16       745059.0
# 17      1400000.0
# 18      1235480.0
# 19      6200000.0
# 20      1499840.0
# 21        34215.0
# 22      1400000.0
# 23     19589000.0
# 24      1040240.0
# 25       847276.0
# 26       881348.0
# 27       847276.0
# 28       847276.0
# 29     11135955.0
#           ...
# 428     7942895.0
# 429      525093.0
# 430      847276.0
# 431     6880802.0
# 432     2794059.0
# 433     5900000.0
# 434     4916000.0
# 435     2975880.0
# 436     4136287.0
# 437     2425160.0
# 438      425093.0
# 439     1315520.0
# 440     2754940.0
# 441     2537720.0
# 442     4675000.0
# 443     2558240.0
# 444     9363484.0
# 445     3677720.0
# 446    11900000.0
# ...

# %%
nba['Weight'].mul(4.3657) 
nba["Weight"] * 4.3657
# Out:
# 0       785.8260
# 1      1025.9395
# 2       894.9685
# 3       807.6545
# 4      1008.4767
# 5      1047.7680
# 6      1025.9395
# 7      1039.0366
# 8       829.4830
# 9       960.4540
# 10     1135.0820
# 11      807.6545
# 12      960.4540
# 13      938.6255
# 14     1104.5221
# 15      942.9912
# 16      829.4830
# 17      873.1400
# 18      960.4540
# 19      873.1400
# 20      908.0656
# 21      956.0883
# 22      763.9975
# 23     1200.5675
# 24      873.1400
# 25      960.4540
# 26     1034.6709
# 27     1082.6936
# 28      894.9685
# 29      964.8197
#          ...
# 428     938.6255
# 429     899.3342
# 430     916.7970
# 431    1047.7680
# 432     938.6255
# 433     938.6255
# 434    1156.9105
# 435    1069.5965
# 436     851.3115
# 437     873.1400
# 438     807.6545
# 439    1025.9395
# 440     755.2661
# 441    1047.7680
# 442     995.3796
# 443     833.8487
# 444     934.2598
# 445     829.4830
# 446    1156.9105
# 447    1069.5965
# 448     986.6482
# ...

# %%
nba['weight to Kg'] = nba['Weight'].mul(4.56)
nba.head(6)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
#
#              College      Salary  weight to Kg
# 0              Texas   7730337.0        820.80
# 1          Marquette   6796117.0       1071.60
# 2  Boston University         NaN        934.80
# 3      Georgia State   1148640.0        843.60
# 4                NaN   5000000.0       1053.36
# 5                NaN  12000000.0       1094.40

# %%
nba['calcu'] = "NaN"
nba.head(2)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
#
#      College     Salary  weight to Kg calcu
# 0      Texas  7730337.0         820.8   NaN
# 1  Marquette  6796117.0        1071.6   NaN

# %%
nba['calcu'] = nba['Salary'] - nba['weight to Kg']
nba.head(2)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
#
#      College     Salary  weight to Kg      calcu
# 0      Texas  7730337.0         820.8  7729516.2
# 1  Marquette  6796117.0        1071.6  6795045.4

# %%
nba.insert(2,column = "Full Name",value=(nba['Name']+'   '+nba['Team']))
nba.head(3)
# Out:
#             Name            Team                       Full Name  Number  \
# 0  Avery Bradley  Boston Celtics  Avery Bradley   Boston Celtics     0.0
# 1    Jae Crowder  Boston Celtics    Jae Crowder   Boston Celtics    99.0
# 2   John Holland  Boston Celtics   John Holland   Boston Celtics    30.0
#
#   Position   Age Height  Weight            College     Salary
# 0       PG  25.0    6-2   180.0              Texas  7730337.0
# 1       SF  25.0    6-6   235.0          Marquette  6796117.0
# 2       SG  27.0    6-5   205.0  Boston University        NaN

# %% [markdown]
# # .value_count() method

# %%
nba = pd.read_csv("nba.csv")
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba['Team'].value_counts()
nba["Weight"].value_counts().head(2)
nba["Position"].value_counts().tail()
nba["Salary"].value_counts()
# Out:
# 947276.0      31
# 845059.0      18
# 525093.0      13
# 981348.0       6
# 1100602.0      5
# 16407500.0     5
# 5000000.0      5
# 12000000.0     5
# 8000000.0      5
# 4000000.0      5
# 3000000.0      4
# 7000000.0      4
# 2814000.0      4
# 1000000.0      4
# 19689000.0     4
# 200600.0       3
# 8500000.0      3
# 2500000.0      3
# 1015421.0      3
# 2854940.0      3
# 13500000.0     3
# 5543725.0      3
# 2288205.0      2
# 1270964.0      2
# 2900000.0      2
# 1007026.0      2
# 111444.0       2
# 13000000.0     2
# 1500000.0      2
# 1842000.0      2
#               ..
# 2239800.0      1
# 1474440.0      1
# 19688000.0     1
# 7900000.0      1
# 2008748.0      1
# 13800000.0     1
# 2841960.0      1
# 1404600.0      1
# 1584480.0      1
# 273038.0       1
# 9213483.0      1
# 3272091.0      1
# 3075880.0      1
# 2250000.0      1
# 4626960.0      1
# 1304520.0      1
# 12100000.0     1
# 7500000.0      1
# 295327.0       1
# 2836186.0      1
# 6486486.0      1
# ...

# %% [markdown]
# # drop columns

# %%
nba = pd.read_csv("nba.csv")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba.tail(3)
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
nba.dropna()
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# 11             Isaiah Thomas          Boston Celtics     4.0       PG  27.0
# 12               Evan Turner          Boston Celtics    11.0       SG  27.0
# 13               James Young          Boston Celtics    13.0       SG  20.0
# ...

# %%
nba.dropna(how="all",inplace=True)
nba.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight   College  \
# 452    Trey Lyles  Utah Jazz    41.0       PF  20.0   6-10   234.0  Kentucky
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0    Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0       NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0       NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0    Kansas
#
#         Salary
# 452  2239800.0
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0

# %%
nba.dropna(axis = 1)
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 2               John Holland          Boston Celtics    30.0       SG  27.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 4              Jonas Jerebko          Boston Celtics     8.0       PF  29.0
# 5               Amir Johnson          Boston Celtics    90.0       PF  29.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# ...

# %%
nba.dropna(subset=["Salary"])
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 4              Jonas Jerebko          Boston Celtics     8.0       PF  29.0
# 5               Amir Johnson          Boston Celtics    90.0       PF  29.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# 11             Isaiah Thomas          Boston Celtics     4.0       PG  27.0
# ...

# %%
a = nba.isnull()
a.head()
# Out:
#     Name   Team  Number  Position    Age  Height  Weight  College  Salary
# 0  False  False   False     False  False   False   False    False   False
# 1  False  False   False     False  False   False   False    False   False
# 2  False  False   False     False  False   False   False    False    True
# 3  False  False   False     False  False   False   False    False   False
# 4  False  False   False     False  False   False   False     True   False

# %%
a =nba.isna()
a.tail()
# Out:
#       Name   Team  Number  Position    Age  Height  Weight  College  Salary
# 452  False  False   False     False  False   False   False    False   False
# 453  False  False   False     False  False   False   False    False   False
# 454  False  False   False     False  False   False   False     True   False
# 455  False  False   False     False  False   False   False     True   False
# 456  False  False   False     False  False   False   False    False   False

# %%
nba["alla"].isnull().mean()>0.5
# Out:
# False

# %%
nba["alla"] = ""
nba
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 2               John Holland          Boston Celtics    30.0       SG  27.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 4              Jonas Jerebko          Boston Celtics     8.0       PF  29.0
# 5               Amir Johnson          Boston Celtics    90.0       PF  29.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# ...

# %%
nba.drop_duplicates(subset="Age")
# Out:
#                 Name                   Team  Number Position   Age Height  \
# 0      Avery Bradley         Boston Celtics     0.0       PG  25.0    6-2
# 2       John Holland         Boston Celtics    30.0       SG  27.0    6-5
# 3        R.J. Hunter         Boston Celtics    28.0       SG  22.0    6-5
# 4      Jonas Jerebko         Boston Celtics     8.0       PF  29.0   6-10
# 6      Jordan Mickey         Boston Celtics    55.0       PF  21.0    6-8
# 10   Jared Sullinger         Boston Celtics     7.0        C  24.0    6-9
# 13       James Young         Boston Celtics    13.0       SG  20.0    6-6
# 14      Tyler Zeller         Boston Celtics    44.0        C  26.0    7-0
# 17   Wayne Ellington          Brooklyn Nets    21.0       SG  28.0    6-4
# 19      Jarrett Jack          Brooklyn Nets     2.0       PG  32.0    6-3
# 22      Shane Larkin          Brooklyn Nets     0.0       PG  23.0   5-11
# 30     Arron Afflalo        New York Knicks     4.0       SG  30.0    6-5
# ...

# %% [markdown]
# # .fillna()

# %%
nba.fillna(value = "something")
# Out:
#                         Name                    Team     Number   Position  \
# 0              Avery Bradley          Boston Celtics          0         PG
# 1                Jae Crowder          Boston Celtics         99         SF
# 2               John Holland          Boston Celtics         30         SG
# 3                R.J. Hunter          Boston Celtics         28         SG
# 4              Jonas Jerebko          Boston Celtics          8         PF
# 5               Amir Johnson          Boston Celtics         90         PF
# 6              Jordan Mickey          Boston Celtics         55         PF
# 7               Kelly Olynyk          Boston Celtics         41          C
# 8               Terry Rozier          Boston Celtics         12         PG
# 9               Marcus Smart          Boston Celtics         36         PG
# 10           Jared Sullinger          Boston Celtics          7          C
# ...

# %%
nba.fillna(value = "hello",axis=0, limit=)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-bf63064d6ef8> in <module>()
# ----> 1 nba.fillna(value = "hello",axis=0, limit="5")
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in fillna(self, value, method, axis, inplace, limit, downcast, **kwargs)
#    3788                      self).fillna(value=value, method=method, axis=axis,
#    3789                                   inplace=inplace, limit=limit,
# -> 3790                                   downcast=downcast, **kwargs)
#    3791
#    3792     @Appender(_shared_docs['replace'] % _shared_doc_kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in fillna(self, value, method, axis, inplace, limit, downcast)
#    5425                 new_data = self._data.fillna(value=value, limit=limit,
#    5426                                              inplace=inplace,
# ...
